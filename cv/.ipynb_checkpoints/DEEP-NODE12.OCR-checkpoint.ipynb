# %% [markdown]
# # 프로젝트: End-to-End OCR

# %% [markdown]
# ## input image

# %%
# $ pip install lmdb

# %%
import re
import six
import math
import lmdb
import os
import numpy as np
import tensorflow as tf

from PIL import Image

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model

BATCH_SIZE = 128
HOME_DIR = os.getenv('HOME')+'/aiffel/ocr'

# 로컬 사용자
TRAIN_DATA_PATH = HOME_DIR+'/MJ/MJ_train'
VALID_DATA_PATH = HOME_DIR+'/MJ/MJ_valid'
TEST_DATA_PATH = HOME_DIR+'/MJ/MJ_test'

# %%
from IPython.display import display

env = lmdb.open(TRAIN_DATA_PATH, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
with env.begin(write=False) as txn:
    for index in range(1, 5):
        label_key = 'label-%09d'.encode() % index
        label = txn.get(label_key).decode('utf-8')
        img_key = 'image-%09d'.encode() % index
        imgbuf = txn.get(img_key)
        buf = six.BytesIO()
        buf.write(imgbuf)
        buf.seek(0)
        try:
            img = Image.open(buf).convert('RGB')

        except IOError:
            img = Image.new('RGB', (100, 32))
            label = '-'
        width, height = img.size
        print('original image width:{}, height:{}'.format(width, height))
        
        target_width = min(int(width*32/height), 100)
        target_img_size = (target_width,32 )
        
        print('target_img_size:{}'.format(target_img_size))
        
        img = np.array(img.resize(target_img_size)).transpose(1,0,2)
       
        print('display img shape:{}'.format(img.shape))
        print('label:{}'.format(label))
        display(Image.fromarray(img.transpose(1,0,2).astype(np.uint8)))
# Out:
# original image width:72, height:31
# target_img_size:(74, 32)
# display img shape:(74, 32, 3)
# label:Lube
# <PIL.Image.Image image mode=RGB size=74x32 at 0x7F0022C99390>
# original image width:82, height:31
# target_img_size:(84, 32)
# display img shape:(84, 32, 3)
# label:Spencerian
# <PIL.Image.Image image mode=RGB size=84x32 at 0x7F0022C99750>
# original image width:115, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:accommodatingly
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F0022C994D0>
# original image width:140, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:CARPENTER
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7F0022C99910>

# %%
class MJDatasetSequence(Sequence):
    def __init__(self, 
                      dataset_path,
                      label_converter,
                      batch_size=1,
                      img_size=(100,32),
                      max_text_len=22,
                      is_train=False,
                      character=''
                ):
        
        self.label_converter = label_converter
        self.batch_size = batch_size
        self.img_size = img_size
        self.max_text_len = max_text_len
        self.character = character
        self.is_train = is_train
        self.divide_length = 100

        self.env = lmdb.open(dataset_path, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
        with self.env.begin(write=False) as txn:
            num_samples = int(txn.get('num-samples'.encode()))
            self.num_samples = int(num_samples)
            self.index_list = [index + 1 for index in range(self.num_samples)]
        
    def __len__(self):
        if self.is_train:
            return math.ceil(self.num_samples/self.batch_size/self.divide_length)
        return math.ceil(self.num_samples/self.batch_size/self.divide_length)
    
    # index에 해당하는 image와 label을 가져오는 메소드
    def _get_img_label(self, index):
        with self.env.begin(write=False) as txn:
            label_key = 'label-%09d'.encode() % index
            label = txn.get(label_key).decode('utf-8')
            img_key = 'image-%09d'.encode() % index
            imgbuf = txn.get(img_key)

            buf = six.BytesIO()
            buf.write(imgbuf)
            buf.seek(0)
            try:
                img = Image.open(buf).convert('RGB')

            except IOError:
                img = Image.new('RGB', self.img_size)
                label = '-'
            width, height = img.size
            
            target_width = min(int(width*self.img_size[1]/height), self.img_size[0])
            target_img_size = (target_width,self.img_size[1] )
            img = np.array(img.resize(target_img_size)).transpose(1,0,2)
            label = label.upper()[:self.max_text_len]
            out_of_char = f'[^{self.character}]'
            label = re.sub(out_of_char, '', label)

        return (img, label)
    
    # idx번째 배치를 가져오는 메소드
    def __getitem__(self, idx):
        batch_indicies = self.index_list[
            idx*self.batch_size:
            (idx+1)*self.batch_size
        ]
        input_images = np.zeros([self.batch_size, *self.img_size, 3])
        labels = np.zeros([self.batch_size, self.max_text_len], dtype='int64')

        input_length = np.ones([self.batch_size], dtype='int64')*self.max_text_len
        label_length = np.ones([self.batch_size], dtype='int64')

        for i, index in enumerate(batch_indicies):
            img, label = self._get_img_label(index)
            encoded_label = self.label_converter.encode(label)
            width = img.shape[0]
            input_images[i,:width,:,:] = img
            if len(encoded_label) > self.max_text_len:
                continue
            labels[i,0:len(encoded_label)] = encoded_label
            label_length[i] = len(encoded_label)

        inputs = {
            'input_image': input_images,
            'label': labels,
            'input_length': input_length,
            'label_length': label_length,
        }
        outputs = {'ctc': np.zeros([self.batch_size, 1])}
        return inputs, outputs
        
    def on_epoch_end(self):
        self.index_list =  [index + 1 for index in range(self.num_samples)]
        if self.is_train :
            np.random.shuffle(self.index_list)
            return self.index_list

# %% [markdown]
# ## encode

# %%
class LabelConverter(object):
     """ Convert between text-label and text-index """

     def __init__(self, character):
         self.character = "-" + character
         self.label_map = dict()
         for i, char in enumerate(self.character):
             self.label_map[char] = i

     def encode(self, text):
         encoded_label = []
         for i, char in enumerate(text):
             if i > 0 and char == text[i - 1]:
                 encoded_label.append(0)    # 같은 문자 사이에 공백 문자 label을 삽입
             encoded_label.append(self.label_map[char])
         return np.array(encoded_label)

     def decode(self, encoded_label):
         target_characters = list(self.character)
         decoded_label = ""
         for encode in encoded_label:
             decoded_label += self.character[encode]
         return decoded_label

# %%
NUMBERS = "0123456789"
ENG_CHAR_UPPER = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
TARGET_CHARACTERS = ENG_CHAR_UPPER + NUMBERS
print(f"The total number of characters is {len(TARGET_CHARACTERS)}")
# Out:
# The total number of characters is 36

# %%
label_converter = LabelConverter(TARGET_CHARACTERS)

encdoded_text = label_converter.encode('HELLO')
print("Encdoded_text: ", encdoded_text)
decoded_text = label_converter.decode(encdoded_text)
print("Decoded_text: ", decoded_text)
# Out:
# Encdoded_text:  [ 8  5 12  0 12 15]
# Decoded_text:  HEL-LO

# %% [markdown]
# ## RCNN

# %%
def ctc_lambda_func(args): # CTC loss를 계산하기 위한 Lambda 함수
    labels, y_pred, label_length, input_length = args
    y_pred = y_pred[:, 2:, :]
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
def build_crnn_model(input_shape=(100,32,3), characters=TARGET_CHARACTERS):
    num_chars = len(characters)+2
    image_input = layers.Input(shape=input_shape, dtype='float32', name='input_image')

    # Build CRNN model
    conv = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(image_input)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)     
    feature = layers.Conv2D(512, (2, 2), activation='relu', kernel_initializer='he_normal')(conv)
    sequnce = layers.Reshape(target_shape=(24, 512))(feature)
    sequnce = layers.Dense(64, activation='relu')(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    y_pred = layers.Dense(num_chars, activation='softmax', name='output')(sequnce)

    labels = layers.Input(shape=[22], dtype='int64', name='label')
    input_length = layers.Input(shape=[1], dtype='int64', name='input_length')
    label_length = layers.Input(shape=[1], dtype='int64', name='label_length')
    loss_out = layers.Lambda(ctc_lambda_func, output_shape=(1,), name="ctc")(
        [labels, y_pred, label_length, input_length]
    )
    model_input = [image_input, labels, input_length, label_length]
    model = Model(
        inputs=model_input,
        outputs=loss_out
    )
    y_func = tf.keras.backend.function(image_input, [y_pred])
    return model, y_func

# %% [markdown]
# ## train & inference

# %%
train_set = MJDatasetSequence(TRAIN_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS, is_train=True)
val_set = MJDatasetSequence(VALID_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)

checkpoint_path = HOME_DIR + '/model_checkpoint.hdf5'

model, y_func = build_crnn_model()
sgd = tf.keras.optimizers.Adadelta(lr=0.1, clipnorm=5)
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=sgd)
ckp = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss',
    verbose=1, save_best_only=True, save_weights_only=True
)
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'
)
model.fit(train_set,
        steps_per_epoch=len(val_set),
        epochs=100,
        validation_data=val_set,
        validation_steps=len(val_set),
        callbacks=[ckp])
# Out:
# Epoch 1/100
# 63/63 [==============================] - ETA: 0s - loss: 28.9879
# Epoch 00001: val_loss improved from inf to 26.98600, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 11s 169ms/step - loss: 28.9879 - val_loss: 26.9860
# Epoch 2/100
# 63/63 [==============================] - ETA: 0s - loss: 26.4534
# Epoch 00002: val_loss improved from 26.98600 to 26.17678, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 26.4534 - val_loss: 26.1768
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 26.0787
# Epoch 00003: val_loss did not improve from 26.17678
# 63/63 [==============================] - 9s 139ms/step - loss: 26.0787 - val_loss: 27.5429
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 25.6094
# Epoch 00004: val_loss improved from 26.17678 to 25.99677, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 145ms/step - loss: 25.6094 - val_loss: 25.9968
# Epoch 5/100
# 63/63 [==============================] - ETA: 0s - loss: 25.1113
# Epoch 00005: val_loss improved from 25.99677 to 25.91965, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 141ms/step - loss: 25.1113 - val_loss: 25.9197
# Epoch 6/100
# 63/63 [==============================] - ETA: 0s - loss: 24.8726
# Epoch 00006: val_loss improved from 25.91965 to 24.80284, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 147ms/step - loss: 24.8726 - val_loss: 24.8028
# Epoch 7/100
# 63/63 [==============================] - ETA: 0s - loss: 23.8413
# Epoch 00007: val_loss did not improve from 24.80284
# 63/63 [==============================] - 9s 142ms/step - loss: 23.8413 - val_loss: 24.9010
# Epoch 8/100
# 63/63 [==============================] - ETA: 0s - loss: 23.0695
# Epoch 00008: val_loss did not improve from 24.80284
# 63/63 [==============================] - 9s 144ms/step - loss: 23.0695 - val_loss: 25.7276
# Epoch 9/100
# 63/63 [==============================] - ETA: 0s - loss: 22.0435
# Epoch 00009: val_loss improved from 24.80284 to 21.80663, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 22.0435 - val_loss: 21.8066
# Epoch 10/100
# 63/63 [==============================] - ETA: 0s - loss: 20.2085
# Epoch 00010: val_loss improved from 21.80663 to 21.16025, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 147ms/step - loss: 20.2085 - val_loss: 21.1603
# Epoch 11/100
# 63/63 [==============================] - ETA: 0s - loss: 18.3011
# Epoch 00011: val_loss improved from 21.16025 to 18.93353, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 18.3011 - val_loss: 18.9335
# Epoch 12/100
# 63/63 [==============================] - ETA: 0s - loss: 15.7169
# Epoch 00012: val_loss improved from 18.93353 to 16.66297, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 146ms/step - loss: 15.7169 - val_loss: 16.6630
# Epoch 13/100
# 63/63 [==============================] - ETA: 0s - loss: 13.4523
# Epoch 00013: val_loss improved from 16.66297 to 14.36361, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 13.4523 - val_loss: 14.3636
# Epoch 14/100
# 63/63 [==============================] - ETA: 0s - loss: 11.6128
# Epoch 00014: val_loss improved from 14.36361 to 12.21474, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 11.6128 - val_loss: 12.2147
# Epoch 15/100
# 63/63 [==============================] - ETA: 0s - loss: 10.6472
# Epoch 00015: val_loss improved from 12.21474 to 10.89377, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 10.6472 - val_loss: 10.8938
# Epoch 16/100
# 63/63 [==============================] - ETA: 0s - loss: 9.8619
# Epoch 00016: val_loss improved from 10.89377 to 10.36970, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 9.8619 - val_loss: 10.3697
# Epoch 17/100
# 63/63 [==============================] - ETA: 0s - loss: 8.7746
# Epoch 00017: val_loss improved from 10.36970 to 9.28352, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 8.7746 - val_loss: 9.2835
# Epoch 18/100
# 63/63 [==============================] - ETA: 0s - loss: 8.3344
# Epoch 00018: val_loss improved from 9.28352 to 8.99232, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 8.3344 - val_loss: 8.9923
# Epoch 19/100
# 63/63 [==============================] - ETA: 0s - loss: 7.8259
# Epoch 00019: val_loss improved from 8.99232 to 8.60710, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 7.8259 - val_loss: 8.6071
# Epoch 20/100
# 63/63 [==============================] - ETA: 0s - loss: 7.5437
# Epoch 00020: val_loss improved from 8.60710 to 7.77884, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 7.5437 - val_loss: 7.7788
# Epoch 21/100
# 63/63 [==============================] - ETA: 0s - loss: 7.2586
# Epoch 00021: val_loss improved from 7.77884 to 7.68480, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 7.2586 - val_loss: 7.6848
# Epoch 22/100
# 63/63 [==============================] - ETA: 0s - loss: 6.7026
# Epoch 00022: val_loss improved from 7.68480 to 7.24431, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 6.7026 - val_loss: 7.2443
# Epoch 23/100
# 63/63 [==============================] - ETA: 0s - loss: 6.7125
# Epoch 00023: val_loss improved from 7.24431 to 6.75244, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 6.7125 - val_loss: 6.7524
# Epoch 24/100
# 63/63 [==============================] - ETA: 0s - loss: 6.3101
# Epoch 00024: val_loss improved from 6.75244 to 6.68672, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 147ms/step - loss: 6.3101 - val_loss: 6.6867
# Epoch 25/100
# 63/63 [==============================] - ETA: 0s - loss: 6.1672
# Epoch 00025: val_loss improved from 6.68672 to 6.45658, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 6.1672 - val_loss: 6.4566
# Epoch 26/100
# 63/63 [==============================] - ETA: 0s - loss: 5.9507
# Epoch 00026: val_loss improved from 6.45658 to 6.28743, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 5.9507 - val_loss: 6.2874
# Epoch 27/100
# 63/63 [==============================] - ETA: 0s - loss: 5.8683
# Epoch 00027: val_loss improved from 6.28743 to 6.18048, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 144ms/step - loss: 5.8683 - val_loss: 6.1805
# Epoch 28/100
# 63/63 [==============================] - ETA: 0s - loss: 5.7022
# Epoch 00028: val_loss improved from 6.18048 to 5.75987, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 5.7022 - val_loss: 5.7599
# Epoch 29/100
# 63/63 [==============================] - ETA: 0s - loss: 5.3949
# Epoch 00029: val_loss did not improve from 5.75987
# 63/63 [==============================] - 9s 142ms/step - loss: 5.3949 - val_loss: 5.8118
# Epoch 30/100
# 63/63 [==============================] - ETA: 0s - loss: 5.2913
# Epoch 00030: val_loss did not improve from 5.75987
# 63/63 [==============================] - 9s 142ms/step - loss: 5.2913 - val_loss: 5.8432
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 5.2748
# Epoch 00031: val_loss improved from 5.75987 to 5.71524, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 5.2748 - val_loss: 5.7152
# Epoch 32/100
# 63/63 [==============================] - ETA: 0s - loss: 5.1604
# Epoch 00032: val_loss improved from 5.71524 to 5.68193, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 5.1604 - val_loss: 5.6819
# Epoch 33/100
# 63/63 [==============================] - ETA: 0s - loss: 4.9894
# Epoch 00033: val_loss improved from 5.68193 to 5.28353, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 4.9894 - val_loss: 5.2835
# Epoch 34/100
# 63/63 [==============================] - ETA: 0s - loss: 4.9077
# Epoch 00034: val_loss did not improve from 5.28353
# 63/63 [==============================] - 9s 142ms/step - loss: 4.9077 - val_loss: 5.5664
# Epoch 35/100
# 63/63 [==============================] - ETA: 0s - loss: 4.8778
# Epoch 00035: val_loss improved from 5.28353 to 5.01494, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 4.8778 - val_loss: 5.0149
# Epoch 36/100
# 63/63 [==============================] - ETA: 0s - loss: 4.8532
# Epoch 00036: val_loss improved from 5.01494 to 4.96416, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 141ms/step - loss: 4.8532 - val_loss: 4.9642
# Epoch 37/100
# 63/63 [==============================] - ETA: 0s - loss: 4.9056
# Epoch 00037: val_loss improved from 4.96416 to 4.83923, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 4.9056 - val_loss: 4.8392
# Epoch 38/100
# 63/63 [==============================] - ETA: 0s - loss: 4.7145
# Epoch 00038: val_loss did not improve from 4.83923
# 63/63 [==============================] - 9s 140ms/step - loss: 4.7145 - val_loss: 5.2908
# Epoch 39/100
# 63/63 [==============================] - ETA: 0s - loss: 4.5750
# Epoch 00039: val_loss improved from 4.83923 to 4.67356, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 4.5750 - val_loss: 4.6736
# Epoch 40/100
# 63/63 [==============================] - ETA: 0s - loss: 4.5204
# Epoch 00040: val_loss did not improve from 4.67356
# 63/63 [==============================] - 9s 141ms/step - loss: 4.5204 - val_loss: 4.6878
# Epoch 41/100
# 63/63 [==============================] - ETA: 0s - loss: 4.3867
# Epoch 00041: val_loss improved from 4.67356 to 4.61713, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 4.3867 - val_loss: 4.6171
# Epoch 42/100
# 63/63 [==============================] - ETA: 0s - loss: 4.4283
# Epoch 00042: val_loss improved from 4.61713 to 4.46540, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 4.4283 - val_loss: 4.4654
# Epoch 43/100
# 63/63 [==============================] - ETA: 0s - loss: 4.2302
# Epoch 00043: val_loss improved from 4.46540 to 4.35892, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 4.2302 - val_loss: 4.3589
# Epoch 44/100
# 63/63 [==============================] - ETA: 0s - loss: 4.1761
# Epoch 00044: val_loss did not improve from 4.35892
# 63/63 [==============================] - 9s 141ms/step - loss: 4.1761 - val_loss: 4.4382
# Epoch 45/100
# 63/63 [==============================] - ETA: 0s - loss: 4.2306
# Epoch 00045: val_loss did not improve from 4.35892
# 63/63 [==============================] - 9s 141ms/step - loss: 4.2306 - val_loss: 4.4631
# Epoch 46/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0876
# Epoch 00046: val_loss did not improve from 4.35892
# 63/63 [==============================] - 9s 142ms/step - loss: 4.0876 - val_loss: 4.3779
# Epoch 47/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0322
# Epoch 00047: val_loss improved from 4.35892 to 4.28345, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 141ms/step - loss: 4.0322 - val_loss: 4.2835
# Epoch 48/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0900
# Epoch 00048: val_loss improved from 4.28345 to 4.08633, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 4.0900 - val_loss: 4.0863
# Epoch 49/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7532
# Epoch 00049: val_loss did not improve from 4.08633
# 63/63 [==============================] - 9s 141ms/step - loss: 3.7532 - val_loss: 4.2019
# Epoch 50/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0185
# Epoch 00050: val_loss improved from 4.08633 to 4.06631, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 4.0185 - val_loss: 4.0663
# Epoch 51/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7468
# Epoch 00051: val_loss improved from 4.06631 to 4.04003, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.7468 - val_loss: 4.0400
# Epoch 52/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8695
# Epoch 00052: val_loss improved from 4.04003 to 3.90924, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.8695 - val_loss: 3.9092
# Epoch 53/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8853
# Epoch 00053: val_loss did not improve from 3.90924
# 63/63 [==============================] - 9s 140ms/step - loss: 3.8853 - val_loss: 3.9961
# Epoch 54/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6903
# Epoch 00054: val_loss improved from 3.90924 to 3.81017, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 3.6903 - val_loss: 3.8102
# Epoch 55/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7505
# Epoch 00055: val_loss did not improve from 3.81017
# 63/63 [==============================] - 9s 140ms/step - loss: 3.7505 - val_loss: 3.9455
# Epoch 56/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6696
# Epoch 00056: val_loss improved from 3.81017 to 3.76611, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 141ms/step - loss: 3.6696 - val_loss: 3.7661
# Epoch 57/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6010
# Epoch 00057: val_loss did not improve from 3.76611
# 63/63 [==============================] - 9s 141ms/step - loss: 3.6010 - val_loss: 3.9366
# Epoch 58/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7453
# Epoch 00058: val_loss did not improve from 3.76611
# 63/63 [==============================] - 9s 142ms/step - loss: 3.7453 - val_loss: 3.8569
# Epoch 59/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5746
# Epoch 00059: val_loss improved from 3.76611 to 3.75656, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 3.5746 - val_loss: 3.7566
# Epoch 60/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4633
# Epoch 00060: val_loss improved from 3.75656 to 3.66237, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.4633 - val_loss: 3.6624
# Epoch 61/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4948
# Epoch 00061: val_loss improved from 3.66237 to 3.65119, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.4948 - val_loss: 3.6512
# Epoch 62/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5883
# Epoch 00062: val_loss improved from 3.65119 to 3.57385, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.5883 - val_loss: 3.5739
# Epoch 63/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4531
# Epoch 00063: val_loss improved from 3.57385 to 3.50761, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 140ms/step - loss: 3.4531 - val_loss: 3.5076
# Epoch 64/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4278
# Epoch 00064: val_loss did not improve from 3.50761
# 63/63 [==============================] - 9s 142ms/step - loss: 3.4278 - val_loss: 4.0053
# Epoch 65/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2157
# Epoch 00065: val_loss improved from 3.50761 to 3.44438, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.2157 - val_loss: 3.4444
# Epoch 66/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4479
# Epoch 00066: val_loss did not improve from 3.44438
# 63/63 [==============================] - 9s 139ms/step - loss: 3.4479 - val_loss: 3.5950
# Epoch 67/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3676
# Epoch 00067: val_loss did not improve from 3.44438
# 63/63 [==============================] - 9s 142ms/step - loss: 3.3676 - val_loss: 3.6322
# Epoch 68/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4155
# Epoch 00068: val_loss improved from 3.44438 to 3.41795, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 3.4155 - val_loss: 3.4179
# Epoch 69/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4385
# Epoch 00069: val_loss improved from 3.41795 to 3.41265, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 3.4385 - val_loss: 3.4127
# Epoch 70/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3493
# Epoch 00070: val_loss did not improve from 3.41265
# 63/63 [==============================] - 9s 142ms/step - loss: 3.3493 - val_loss: 3.5647
# Epoch 71/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2092
# Epoch 00071: val_loss did not improve from 3.41265
# 63/63 [==============================] - 9s 140ms/step - loss: 3.2092 - val_loss: 3.4541
# Epoch 72/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1739
# Epoch 00072: val_loss improved from 3.41265 to 3.25948, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 3.1739 - val_loss: 3.2595
# Epoch 73/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2266
# Epoch 00073: val_loss did not improve from 3.25948
# 63/63 [==============================] - 9s 140ms/step - loss: 3.2266 - val_loss: 3.4665
# Epoch 74/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1714
# Epoch 00074: val_loss did not improve from 3.25948
# 63/63 [==============================] - 9s 142ms/step - loss: 3.1714 - val_loss: 3.2972
# Epoch 75/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0987
# Epoch 00075: val_loss improved from 3.25948 to 3.23687, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 141ms/step - loss: 3.0987 - val_loss: 3.2369
# Epoch 76/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1167
# Epoch 00076: val_loss did not improve from 3.23687
# 63/63 [==============================] - 9s 140ms/step - loss: 3.1167 - val_loss: 3.3508
# Epoch 77/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1001
# Epoch 00077: val_loss did not improve from 3.23687
# 63/63 [==============================] - 9s 142ms/step - loss: 3.1001 - val_loss: 3.2555
# Epoch 78/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9875
# Epoch 00078: val_loss improved from 3.23687 to 3.22872, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 2.9875 - val_loss: 3.2287
# Epoch 79/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0184
# Epoch 00079: val_loss did not improve from 3.22872
# 63/63 [==============================] - 9s 142ms/step - loss: 3.0184 - val_loss: 3.2800
# Epoch 80/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9289
# Epoch 00080: val_loss did not improve from 3.22872
# 63/63 [==============================] - 9s 141ms/step - loss: 2.9289 - val_loss: 3.4494
# Epoch 81/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9692
# Epoch 00081: val_loss did not improve from 3.22872
# 63/63 [==============================] - 9s 140ms/step - loss: 2.9692 - val_loss: 3.4715
# Epoch 82/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2336
# Epoch 00082: val_loss improved from 3.22872 to 3.08254, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 3.2336 - val_loss: 3.0825
# Epoch 83/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9748
# Epoch 00083: val_loss did not improve from 3.08254
# 63/63 [==============================] - 9s 140ms/step - loss: 2.9748 - val_loss: 3.2452
# Epoch 84/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9156
# Epoch 00084: val_loss improved from 3.08254 to 3.06844, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 2.9156 - val_loss: 3.0684
# Epoch 85/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8645
# Epoch 00085: val_loss improved from 3.06844 to 3.03275, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 2.8645 - val_loss: 3.0328
# Epoch 86/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9776
# Epoch 00086: val_loss did not improve from 3.03275
# 63/63 [==============================] - 9s 140ms/step - loss: 2.9776 - val_loss: 3.0390
# Epoch 87/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9611
# Epoch 00087: val_loss improved from 3.03275 to 3.00061, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 2.9611 - val_loss: 3.0006
# Epoch 88/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9288
# Epoch 00088: val_loss did not improve from 3.00061
# 63/63 [==============================] - 9s 141ms/step - loss: 2.9288 - val_loss: 3.0720
# Epoch 89/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9456
# Epoch 00089: val_loss did not improve from 3.00061
# 63/63 [==============================] - 9s 141ms/step - loss: 2.9456 - val_loss: 3.0268
# Epoch 90/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8776
# Epoch 00090: val_loss improved from 3.00061 to 2.94117, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 142ms/step - loss: 2.8776 - val_loss: 2.9412
# Epoch 91/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8566
# Epoch 00091: val_loss did not improve from 2.94117
# 63/63 [==============================] - 9s 141ms/step - loss: 2.8566 - val_loss: 3.0015
# Epoch 92/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8568
# Epoch 00092: val_loss did not improve from 2.94117
# 63/63 [==============================] - 9s 142ms/step - loss: 2.8568 - val_loss: 2.9715
# Epoch 93/100
# 63/63 [==============================] - ETA: 0s - loss: 2.7524
# Epoch 00093: val_loss improved from 2.94117 to 2.92500, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 141ms/step - loss: 2.7524 - val_loss: 2.9250
# Epoch 94/100
# 63/63 [==============================] - ETA: 0s - loss: 2.7964
# Epoch 00094: val_loss improved from 2.92500 to 2.87564, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 146ms/step - loss: 2.7964 - val_loss: 2.8756
# Epoch 95/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8066
# Epoch 00095: val_loss did not improve from 2.87564
# 63/63 [==============================] - 9s 140ms/step - loss: 2.8066 - val_loss: 3.0748
# Epoch 96/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8427
# Epoch 00096: val_loss did not improve from 2.87564
# 63/63 [==============================] - 9s 141ms/step - loss: 2.8427 - val_loss: 2.8956
# Epoch 97/100
# 63/63 [==============================] - ETA: 0s - loss: 2.7440
# Epoch 00097: val_loss did not improve from 2.87564
# 63/63 [==============================] - 9s 141ms/step - loss: 2.7440 - val_loss: 2.8870
# Epoch 98/100
# 63/63 [==============================] - ETA: 0s - loss: 2.7513
# Epoch 00098: val_loss did not improve from 2.87564
# 63/63 [==============================] - 9s 141ms/step - loss: 2.7513 - val_loss: 2.9232
# Epoch 99/100
# 63/63 [==============================] - ETA: 0s - loss: 2.7431
# Epoch 00099: val_loss improved from 2.87564 to 2.78293, saving model to /home/ssac26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 9s 143ms/step - loss: 2.7431 - val_loss: 2.7829
# Epoch 100/100
# 63/63 [==============================] - ETA: 0s - loss: 2.6267
# Epoch 00100: val_loss did not improve from 2.78293
# 63/63 [==============================] - 9s 141ms/step - loss: 2.6267 - val_loss: 2.8361

# %%
from IPython.display import display

test_set = MJDatasetSequence(TEST_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)

model, y_func = build_crnn_model()

model.load_weights(checkpoint_path)
input_data = model.get_layer('input_image').output
y_pred = model.get_layer('output').output
model_pred = Model(inputs=input_data, outputs=y_pred)

def decode_predict_ctc(out, chars = TARGET_CHARACTERS, top_paths = 1):
    results = []
    beam_width = 5
    if beam_width < top_paths:
        beam_width = top_paths
    for i in range(top_paths):
        indexes = K.get_value(
            K.ctc_decode(
                out, input_length = np.ones(out.shape[0]) * out.shape[1],
                greedy =False , beam_width = beam_width, top_paths = top_paths
            )[0][i]
        )[0]
        text = ""
        for index in indexes:
            text += chars[index]
        results.append(text)
    return results

def check_inference(model, dataset, index = 5):
    for i in range(index):
        inputs, outputs = dataset[i]
        img = dataset[i][0]['input_image'][0:1,:,:,:]
        output = model_pred.predict(img)
        result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
        print("Result: \t", result)
        display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

check_inference(model, test_set, index=10)
# Out:
# WARNING:tensorflow:From /home/ssac26/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Result: 	 SLINKING9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF5747D6110>
# Result: 	 ALEPPO99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF4BC1530D0>
# Result: 	 IWENDA999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573F84CD0>
# Result: 	 NATHANS99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573F372D0>
# Result: 	 HALLO999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573DDC390>
# Result: 	 HURLS9999999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573DD25D0>
# Result: 	 DOWNSIZE9999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573DA5E90>
# Result: 	 ROBOTIC99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573D79B50>
# Result: 	 SLOPPY99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573D79650>
# Result: 	 HERMITE99999999999999999
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7EF573F80450>

# %% [markdown]
# ## End-to-End OCR

# %%
from keras_ocr.detection import Detector
SAMPLE_IMG_PATH = 'sample.jpg'

detector = Detector()
# Out:
# Looking for /home/ssac26/.keras-ocr/craft_mlt_25k.h5

# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

from keras_ocr.detection import Detector
SAMPLE_IMG_PATH =os.getenv('HOME')+ '/aiffel/ocr/sample.jpg'

detector = Detector()
# Out:
# Looking for /home/ssac26/.keras-ocr/craft_mlt_25k.h5

# %%
def detect_text(img_path):
    img = cv2.imread(img_path)
    line_img = img.copy()
    input_img = img[tf.newaxis,...]
    result=detector.detect(input_img)
    #print("result", result, "\n")
    ocr_result = result[0]
    #print("ocr_result", ocr_result, "\n")
    cropped_imgs = []
    for text_result in ocr_result:
        #print("text_result", text_result, "\n")
        for i in range(4):
            if i==3:
                # cv2.line(image, start_point, end_point, color, thickness)
                line_img = cv2.line(line_img,tuple(text_result[3]),tuple(text_result[0]),(0,0,255),10)
            else:
                line_img = cv2.line(line_img,tuple(text_result[i]),tuple(text_result[i+1]),(0,0,255),10)
        x_min = text_result[:,0].min() - 5
        x_max = text_result[:,0].max() + 5
        y_min = text_result[:,1].min() - 5
        y_max = text_result[:,1].max() + 5
        cropped_imgs.append(img[int(y_min):int(y_max),int(x_min):int(x_max)])
    return line_img, cropped_imgs

# %%
pwd
# Out:
# '/home/ssac26/ssac_notebook/Deeper'

# %%
SAMPLE_IMG_PATH
# Out:
# '/home/ssac26/aiffel/ocr/sample.jpg'

# %%
img, cropped_img = detect_text(SAMPLE_IMG_PATH)
plt.imshow(img[:,:,::-1])

# %%
plt.imshow(cropped_img[0])

# %%
def recognize_img(input_img, input_img_size=(100,32)):
    # 잘려진 단어 이미지를 인식하는 코드
    img = cv2.resize(input_img, input_img_size)
    print(img.shape)
    
    result_img = img.copy()
    output = model_pred.predict(img)
    result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
    print("Result: \t", result)
    display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

# %% [markdown]
# 실습이 끝까지 완벽하게 진행되지는 않았지만, 다른 기술들에 비해 실생활에서 캡쳐번역을 이용해 종종 접하던 기술이 실제론 어떻게 작동하는지 알 수 있었다.
